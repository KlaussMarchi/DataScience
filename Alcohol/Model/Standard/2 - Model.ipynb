# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import json, os, joblib, math
from itertools import product

import matplotlib.ticker as mticker
import pandas as pd

# %% [markdown]
# # EXTRAINDO DADOS

# %%
df     = pd.read_csv('../../Dataset/model.csv')
TARGET = 'alcohol'
K_CV   = 5
df.head(3)
# Out:
#    decay  mean_diff    min          mean   median   last  rise         std  \
# 0    284  -0.382979  23250  23557.723404  23281.0  23275 -2682  750.506487
# 1    261  -0.361702  23536  23877.446809  23585.0  23596 -2346  756.473851
# 2    204   8.680851  23695  24055.574468  23765.0  23801 -2460  757.619921
#
#    amplitude  max_diff  min_diff    max  first_diff  median_diff    std_diff  \
# 0       2966    1341.0   -1006.5  26216       479.0         -2.0  334.276298
# 1       2607    1168.5    -858.5  26143       367.0          0.5  297.088420
# 2       2664    1175.0    -862.0  26359      1006.0          2.0  312.737500
#
#    alcohol                                               data
# 0    False  [23534, 24013, 26216, 26172, 26108, 25037, 240...
# 1    False  [23797, 24164, 26134, 26143, 26142, 26120, 253...
# 2    False  [23899, 24905, 26249, 26359, 26335, 26225, 254...

# %%
xData = df.drop(columns=[TARGET, 'data'])
yData = df[TARGET].values

N_STATES = len(xData.columns)
print('n states: ', N_STATES)

xData
# Out:
# n states:  15
#      decay   mean_diff    min          mean   median   last  rise  \
# 0      284   -0.382979  23250  23557.723404  23281.0  23275 -2682
# 1      261   -0.361702  23536  23877.446809  23585.0  23596 -2346
# 2      204    8.680851  23695  24055.574468  23765.0  23801 -2460
# 3      444   -4.787234  23523  24066.489362  23586.0  23553 -2318
# 4       33    6.361702  23826  24297.723404  23938.0  23943 -2410
# ..     ...         ...    ...           ...      ...    ...   ...
# 900      0   62.414894  10531  12953.191489  12786.0  12897 -6063
# 901      0   32.872340  12332  14325.957447  13946.0  13399 -6210
# 902      0   34.095745  13450  15362.808511  14937.0  14397 -6359
# 903      0   57.276596  13804  16253.957447  15819.0  15673 -7025
# 904   7289 -143.138298   7924  10123.340426   8390.0   7937 -4222
#
#              std  amplitude  max_diff  min_diff    max  first_diff  \
# 0     750.506487       2966    1341.0   -1006.5  26216       479.0
# 1     756.473851       2607    1168.5    -858.5  26143       367.0
# 2     757.619921       2664    1175.0    -862.0  26359      1006.0
# 3     951.326599       2762    1159.0    -796.0  26285       417.0
# 4     723.535964       2443    1205.0    -849.5  26269       428.0
# ..           ...        ...       ...       ...    ...         ...
# 900  1120.923913       6063    2563.0   -1726.5  16594      1117.0
# 901  1327.147087       6210    3105.0   -1788.0  18542      1388.0
# 902  1396.709326       6359    3179.5   -1123.0  19809      1502.0
# 903  1478.439938       7025    3512.5   -1871.5  20829      1667.0
# 904  3444.633099      11511    2111.0   -2491.5  19435      1148.0
#
#      median_diff    std_diff
# 0           -2.0  334.276298
# 1            0.5  297.088420
# 2            2.0  312.737500
# 3           -3.5  286.202777
# 4            2.0  397.356656
# ..           ...         ...
# 900         18.0  623.389667
# 901        -10.0  709.280732
# 902        -23.0  678.700418
# 903        -11.5  783.304627
# 904        -42.5  668.580421
#
# [905 rows x 15 columns]

# %% [markdown]
# # SELECIONANDO MODELO

# %%
from Selector.index import ModelSelector

# %%
selector = ModelSelector('random_forest')
model, params = selector.get()
model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(n_estimators=300, random_state=42))])

# %% [markdown]
# # APLICANDO GRID SEARCH

# %%
from GridSearch.index import GridSearch

# %%
grid = GridSearch(model, params, xData, yData, K_CV)
grid.update()

model, auc = grid.evaluate()
print('best_auc:', auc)
model
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# best_auc: 0.9915750915750916
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(max_depth=10, min_samples_split=5,
#                                         n_estimators=500, random_state=42))])

# %% [markdown]
# # AVALIAÇÃO GAUSSIANA
# O valor mais provável em uma distribuição gaussiana é a média, com a relação
#
# $$\mu \pm t\cdot\frac{\sigma_a}{\sqrt{n}}$$
#
# - $\sigma_a$ é o desvio padrão amostral, considerando $n-1$ graus de liberade (ddof no numpy)
# - $\mu$ é a média
# - $t$ é o t_student para corrigir a amostra com $n$-1 e aqui vamos adotar a tabela para 95% de confiança (os dados vão cair em um intervalo $\pm$ ... com 95% de confiança)

# %%
from Metrics.CrossValidation.index import CrossValidation
from Metrics.GaussianAnalyser.index import GaussianAnalyser

# %%
cross    = CrossValidation(model, xData, yData, K_CV)
analyser = GaussianAnalyser(cross)
analyser.update()
analyser.plot()
analyser.info()
# Out:
# {'accuracy': 0.9733701657458561,
#  'precision': 0.9737436498992375,
#  'recall': 0.9733701657458561,
#  'auc': 0.9969328449328451}

# %% [markdown]
# # RESULTADOS

# %%
from Metrics.ROC.index import RocCurve
from Metrics.ConfusionMatrix.index import ConfusionMatrix
from Metrics.Plotter.index import Plotter

# %%
analyser.cross.print()
# Out:
# ACCURACY: 97.127% (±1.07%)
# PRECISION: 97.165% (±1.05%)
# RECALL: 97.127% (±1.07%)
# ROC_AUC: 99.712% (±0.08%)
#         name                                             values      mean  \
# 0   accuracy  [0.9723756906077348, 0.9723756906077348, 0.966...  0.971271
# 1  precision  [0.9728904796455659, 0.972900228447368, 0.9668...  0.971655
# 2     recall  [0.9723756906077348, 0.9723756906077348, 0.966...  0.971271
# 3    roc_auc  [0.9965811965811965, 0.9970695970695971, 0.998...  0.997118
#
#         std       min       max        k0        k1        k2       k3  \
# 0  0.010713  0.955801  0.988950  0.972376  0.972376  0.966851  0.98895
# 1  0.010483  0.956683  0.988950  0.972890  0.972900  0.966851  0.98895
# 2  0.010713  0.955801  0.988950  0.972376  0.972376  0.966851  0.98895
# 3  0.000763  0.996337  0.998535  0.996581  0.997070  0.998535  0.99707
#
#          k4
# 0  0.955801
# 1  0.956683
# 2  0.955801
# 3  0.996337

# %%
analyser.cross.plot()

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 1)
ConfusionMatrix(model, xData, yData, cross.cv).plot()

plt.subplot(1, 3, 2)
Plotter(analyser.info(), limits=(0, 1.10))

plt.subplot(1, 3, 3)
RocCurve(model, xData, yData, cross.cv).plot()

# %% [markdown]
# # TREINANDO MODELO FINAL

# %%
from sklearn.metrics import roc_curve, accuracy_score
from sklearn.preprocessing import label_binarize

# %%
model.fit(xData, yData)
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('model',
#    RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=500,
#                           random_state=42))],
#  'transform_input': None,
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'model': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=500,
#                         random_state=42),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'model__bootstrap': True,
#  'model__ccp_alpha': 0.0,
#  'model__class_weight': None,
#  'model__criterion': 'gini',
#  'model__max_depth': 10,
#  'model__max_features': 'sqrt',
#  'model__max_leaf_nodes': None,
#  'model__max_samples': None,
#  'model__min_impurity_decrease': 0.0,
#  'model__min_samples_leaf': 1,
#  'model__min_samples_split': 5,
#  'model__min_weight_fraction_leaf': 0.0,
#  'model__monotonic_cst': None,
#  'model__n_estimators': 500,
#  'model__n_jobs': None,
#  'model__oob_score': False,
#  'model__random_state': 42,
#  'model__verbose': 0,
#  'model__warm_start': False}

# %%
yProba = model.predict_proba(xData)
yBin   = label_binarize(yData, classes=model.classes_)

if yBin.shape[1] == 1 and len(model.classes_) == 2:
    yBin = np.hstack((1 - yBin, yBin))

treshHistory  = []
bestTresholds = {}
scaled_probas = np.zeros_like(yProba)

for i in range(len(model.classes_)):
    fpr, tpr, thresholds = roc_curve(yBin[:, i], yProba[:, i])    
    J   = tpr - fpr
    idx = np.argmax(J)
    best_thresh = thresholds[idx] if thresholds[idx] > 0.01 else 0.01 
    
    bestTresholds[model.classes_[i]] = best_thresh
    scaled_probas[:, i] = yProba[:, i] / best_thresh
    data = {'class': model.classes_[i], 'treshold': best_thresh}
    treshHistory.append(data)
    print(data)

yStandard = model.classes_[np.argmax(yProba, axis=1)]
yBest     = model.classes_[np.argmax(scaled_probas, axis=1)]

acc_padrao = accuracy_score(yData, yStandard) * 100
acc_best   = accuracy_score(yData, yBest)     * 100

print()
print(f'Acurácia Padrão (Argmax): {acc_padrao:.3f}%')
print(f'Acurácia Ótima (Scaled):  {acc_best:.3f}%')
# Out:
# {'class': np.False_, 'treshold': np.float64(0.4608111832611833)}
# {'class': np.True_, 'treshold': np.float64(0.5783238095238094)}
#
# Acurácia Padrão (Argmax): 99.890%
# Acurácia Ótima (Scaled):  100.000%

# %%
model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(max_depth=10, min_samples_split=5,
#                                         n_estimators=500, random_state=42))])

# %% [markdown]
# # SALVANDO O MODELO

# %%
os.makedirs('Backup', exist_ok=True)
index  = len(os.listdir('Backup')) + 1

output = f'Backup/model_{index}'
os.makedirs(output, exist_ok=True)

results = {
    'model': selector.chosen,
    'folder': f'model_{index}',
    'params': {key: str(value) for key, value in model.get_params().items()},
    'K_CV': K_CV,
    'info': analyser.info(),
    'thresholds': treshHistory,
    'variables': xData.columns.tolist()
}

pd.Series(results).to_json(os.path.join(output, 'info.json'), indent=4)
joblib.dump(model, os.path.join(output, 'model.pkl'))

display(pd.DataFrame([results.get('info')]))
results
# Out:
#    accuracy  precision   recall       auc
# 0   0.97337   0.973744  0.97337  0.996933
# {'model': 'random_forest',
#  'folder': 'model_1',
#  'params': {'memory': 'None',
#   'steps': "[('scaler', StandardScaler()), ('model', RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=500,\n                       random_state=42))]",
#   'transform_input': 'None',
#   'verbose': 'False',
#   'scaler': 'StandardScaler()',
#   'model': 'RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=500,\n                       random_state=42)',
#   'scaler__copy': 'True',
#   'scaler__with_mean': 'True',
#   'scaler__with_std': 'True',
#   'model__bootstrap': 'True',
#   'model__ccp_alpha': '0.0',
#   'model__class_weight': 'None',
#   'model__criterion': 'gini',
#   'model__max_depth': '10',
#   'model__max_features': 'sqrt',
#   'model__max_leaf_nodes': 'None',
#   'model__max_samples': 'None',
#   'model__min_impurity_decrease': '0.0',
#   'model__min_samples_leaf': '1',
#   'model__min_samples_split': '5',
#   'model__min_weight_fraction_leaf': '0.0',
#   'model__monotonic_cst': 'None',
#   'model__n_estimators': '500',
#   'model__n_jobs': 'None',
#   'model__oob_score': 'False',
#   'model__random_state': '42',
#   'model__verbose': '0',
#   'model__warm_start': 'False'},
#  'K_CV': 5,
#  'info': {'accuracy': 0.9733701657458561,
#   'precision': 0.9737436498992375,
#   'recall': 0.9733701657458561,
#   'auc': 0.9969328449328451},
#  'thresholds': [{'class': np.False_,
#    'treshold': np.float64(0.4608111832611833)},
#   {'class': np.True_, 'treshold': np.float64(0.5783238095238094)}],
#  'variables': ['decay',
#   'mean_diff',
#   'min',
#   'mean',
#   'median',
#   'last',
#   'rise',
#   'std',
#   'amplitude',
#   'max_diff',
#   'min_diff',
#   'max',
#   'first_diff',
#   'median_diff',
#   'std_diff']}
